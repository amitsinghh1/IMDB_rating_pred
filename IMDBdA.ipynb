# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\HP Pavilion\OneDrive\Documents\projects\movie_metadata.csv")

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# plot_keywords                4890 non-null object
# movie_imdb_link              5043 non-null object
# num_user_for_reviews         5022 non-null float64
# language                     5031 non-null object
# country                      5038 non-null object
# content_rating               4740 non-null object
# budget                       4551 non-null float64
# title_year                   4935 non-null float64
# actor_2_facebook_likes       5030 non-null float64
# imdb_score                   5043 non-null float64
# aspect_ratio                 4714 non-null float64
# movie_facebook_likes         5043 non-null int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                133.000000              614.000000  5.340988e+06
# 50%                371.500000              988.000000  2.551750e+07
# 75%                636.000000            11000.000000  6.230944e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     5.043000e+03                5043.000000           5030.000000
# mean      8.366816e+04                9699.063851              1.371173
# std       1.384853e+05               18163.799124              2.013576
# min       5.000000e+00                   0.000000              0.000000
# 25%       8.593500e+03                1411.000000              0.000000
# 50%       3.435900e+04                3090.000000              1.000000
# 75%       9.630900e+04               13756.500000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           5022.000000  4.551000e+03  4935.000000
# mean             272.770808  3.975262e+07  2002.470517
# std              377.982886  2.061149e+08    12.474599
# min                1.000000  2.180000e+02  1916.000000
# 25%               65.000000  6.000000e+06  1999.000000
# 50%              156.000000  2.000000e+07  2005.000000
# 75%              326.000000  4.500000e+07  2011.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             5030.000000  5043.000000   4714.000000           5043.000000
# mean              1651.754473     6.442138      2.220403           7525.964505
# std               4042.438863     1.125116      1.385113          19320.445110
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                281.000000     5.800000      1.850000              0.000000
# 50%                595.000000     6.600000      2.350000            166.000000
# 75%                918.000000     7.200000      2.350000           3000.000000
# max             137000.000000     9.500000     16.000000         349000.000000

# %%
df.describe(include='O')
# Out:
#         color     director_name    actor_2_name genres    actor_1_name  \
# count    5024              4939            5030   5043            5036
# unique      2              2398            3032    914            2097
# top     Color  Steven Spielberg  Morgan Freeman  Drama  Robert De Niro
# freq     4815                26              20    236              49
#
#                  movie_title  actor_3_name   plot_keywords  \
# count                   5043          5020            4890
# unique                  4917          3521            4760
# top     Victor Frankenstein   Steve Coogan  based on novel
# freq                       3             8               4
#
#                                           movie_imdb_link language country  \
# count                                                5043     5031    5038
# unique                                               4919       47      65
# top     http://www.imdb.com/title/tt0232500/?ref_=fn_t...  English     USA
# freq                                                    3     4704    3807
#
#        content_rating
# count            4740
# unique             18
# top                 R
# freq             2118

# %%
df.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3756 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        3756 non-null object
# director_name                3756 non-null object
# num_critic_for_reviews       3756 non-null float64
# duration                     3756 non-null float64
# director_facebook_likes      3756 non-null float64
# actor_3_facebook_likes       3756 non-null float64
# actor_2_name                 3756 non-null object
# actor_1_facebook_likes       3756 non-null float64
# gross                        3756 non-null float64
# genres                       3756 non-null object
# actor_1_name                 3756 non-null object
# movie_title                  3756 non-null object
# num_voted_users              3756 non-null int64
# cast_total_facebook_likes    3756 non-null int64
# actor_3_name                 3756 non-null object
# facenumber_in_poster         3756 non-null float64
# plot_keywords                3756 non-null object
# movie_imdb_link              3756 non-null object
# num_user_for_reviews         3756 non-null float64
# language                     3756 non-null object
# country                      3756 non-null object
# content_rating               3756 non-null object
# budget                       3756 non-null float64
# title_year                   3756 non-null float64
# actor_2_facebook_likes       3756 non-null float64
# imdb_score                   3756 non-null float64
# aspect_ratio                 3756 non-null float64
# movie_facebook_likes         3756 non-null int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 851.0+ KB

# %%
df.movie_title.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5038    False
# 5039    False
# 5040    False
# 5041    False
# 5042    False
# Name: movie_title, Length: 5043, dtype: bool

# %%
df_copy=df.copy()

# %%
df_copy.drop_duplicates(['movie_title'],inplace=True)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4917 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        4898 non-null object
# director_name                4815 non-null object
# num_critic_for_reviews       4868 non-null float64
# duration                     4902 non-null float64
# director_facebook_likes      4815 non-null float64
# actor_3_facebook_likes       4894 non-null float64
# actor_2_name                 4904 non-null object
# actor_1_facebook_likes       4910 non-null float64
# gross                        4054 non-null float64
# genres                       4917 non-null object
# actor_1_name                 4910 non-null object
# movie_title                  4917 non-null object
# num_voted_users              4917 non-null int64
# cast_total_facebook_likes    4917 non-null int64
# actor_3_name                 4894 non-null object
# facenumber_in_poster         4904 non-null float64
# plot_keywords                4765 non-null object
# movie_imdb_link              4917 non-null object
# num_user_for_reviews         4896 non-null float64
# language                     4905 non-null object
# country                      4912 non-null object
# content_rating               4617 non-null object
# budget                       4433 non-null float64
# title_year                   4811 non-null float64
# actor_2_facebook_likes       4904 non-null float64
# imdb_score                   4917 non-null float64
# aspect_ratio                 4591 non-null float64
# movie_facebook_likes         4917 non-null int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB

# %%
df_copy.describe(include='O')
# Out:
#         color     director_name    actor_2_name genres    actor_1_name  \
# count    4898              4815            4904   4917            4910
# unique      2              2397            3030    914            2095
# top     Color  Steven Spielberg  Morgan Freeman  Drama  Robert De Niro
# freq     4694                26              18    233              48
#
#            movie_title  actor_3_name   plot_keywords  \
# count             4917          4894            4765
# unique            4917          3519            4757
# top     The Borrowers   Steve Coogan  based on novel
# freq                 1             8               4
#
#                                           movie_imdb_link language country  \
# count                                                4917     4905    4912
# unique                                               4917       47      65
# top     http://www.imdb.com/title/tt1781922/?ref_=fn_t...  English     USA
# freq                                                    1     4583    3711
#
#        content_rating
# count            4617
# unique             18
# top                 R
# freq             2068

# %%
df_copy.drop('movie_imdb_link',axis=1)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 5038                   637.0          NaN                     Comedy|Drama
# 5039                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 5040                     0.0          NaN            Drama|Horror|Thriller
# 5041                   946.0      10443.0             Comedy|Drama|Romance
# 5042                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 5038  ...                  6.0  English   Canada             NaN          NaN
# 5039  ...                359.0  English      USA           TV-14          NaN
# 5040  ...                  3.0  English      USA             NaN       1400.0
# 5041  ...                  9.0  English      USA           PG-13          NaN
# 5042  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes  imdb_score aspect_ratio  \
# 0         2009.0                  936.0         7.9         1.78
# 1         2007.0                 5000.0         7.1         2.35
# 2         2015.0                  393.0         6.8         2.35
# 3         2012.0                23000.0         8.5         2.35
# 4            NaN                   12.0         7.1          NaN
# ...          ...                    ...         ...          ...
# 5038      2013.0                  470.0         7.7          NaN
# 5039         NaN                  593.0         7.5        16.00
# 5040      2013.0                    0.0         6.3          NaN
# 5041      2012.0                  719.0         6.3         2.35
# 5042      2004.0                   23.0         6.6         1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 5038                   84
# 5039                32000
# 5040                   16
# 5041                  660
# 5042                  456
#
# [4917 rows x 27 columns]

# %%
df.duration.plot()

# %%
plt.scatter(df['duration'],df['budget']/1000000000)
plt.xlabel('duration')
plt.ylabel('budget')
# Out:
# Text(0, 0.5, 'budget')

# %%
import seaborn as sns

# %%
df_copy.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4868.000000  4902.000000              4815.000000
# mean               137.983566   107.089963               690.871028
# std                120.227603    25.283503              2832.677373
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4894.000000             4910.000000  4.054000e+03
# mean               631.203515             6493.369450  4.764451e+07
# std               1625.716627            15105.651622  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                132.000000              607.000000  5.019656e+06
# 50%                366.000000              982.000000  2.504396e+07
# 75%                633.000000            11000.000000  6.110841e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     4.917000e+03                4917.000000           4904.000000
# mean      8.263723e+04                9578.276998              1.377039
# std       1.383091e+05               18162.789993              2.023715
# min       5.000000e+00                   0.000000              0.000000
# 25%       8.367000e+03                1395.000000              0.000000
# 50%       3.315800e+04                3049.000000              1.000000
# 75%       9.376700e+04               13616.000000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           4896.000000  4.433000e+03  4811.000000
# mean             267.651348  3.654150e+07  2002.443567
# std              372.898753  1.002322e+08    12.455838
# min                1.000000  2.180000e+02  1916.000000
# 25%               64.000000  6.000000e+06  1999.000000
# 50%              153.500000  1.980000e+07  2005.000000
# 75%              320.250000  4.300000e+07  2011.000000
# max             5060.000000  4.200000e+09  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             4904.000000  4917.000000   4591.000000           4917.000000
# mean              1621.649470     6.437584      2.222267           7346.799675
# std               4010.936348     1.127740      1.402798          19204.348861
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                277.000000     5.800000      1.850000              0.000000
# 50%                593.000000     6.600000      2.350000            158.000000
# 75%                912.000000     7.200000      2.350000           2000.000000
# max             137000.000000     9.500000     16.000000         349000.000000

# %%
corr=df_copy.corr()
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(corr,annot=True,linewidths=0.5,square=True,cmap='Blues',ax=ax)

# %%
df_copy=df_copy.drop(['facenumber_in_poster','title_year','aspect_ratio','movie_imdb_link'],axis=1)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4917 entries, 0 to 5042
# Data columns (total 24 columns):
# color                        4898 non-null object
# director_name                4815 non-null object
# num_critic_for_reviews       4868 non-null float64
# duration                     4902 non-null float64
# director_facebook_likes      4815 non-null float64
# actor_3_facebook_likes       4894 non-null float64
# actor_2_name                 4904 non-null object
# actor_1_facebook_likes       4910 non-null float64
# gross                        4054 non-null float64
# genres                       4917 non-null object
# actor_1_name                 4910 non-null object
# movie_title                  4917 non-null object
# num_voted_users              4917 non-null int64
# cast_total_facebook_likes    4917 non-null int64
# actor_3_name                 4894 non-null object
# plot_keywords                4765 non-null object
# num_user_for_reviews         4896 non-null float64
# language                     4905 non-null object
# country                      4912 non-null object
# content_rating               4617 non-null object
# budget                       4433 non-null float64
# actor_2_facebook_likes       4904 non-null float64
# imdb_score                   4917 non-null float64
# movie_facebook_likes         4917 non-null int64
# dtypes: float64(10), int64(3), object(11)
# memory usage: 960.4+ KB

# %%
corr=df_copy.corr()
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(corr,annot=True,linewidths=0.5,square=True,cmap='Blues',ax=ax)

# %%
df_copy['color']=df['color']

# %%
df_copy.iloc[4900:4917,0:3]
# Out:
#                  color       director_name  num_critic_for_reviews
# 5026             Color     Olivier Assayas                    81.0
# 5027             Color        Jafar Panahi                    64.0
# 5028   Black and White       Ivan Kavanagh                    12.0
# 5029             Color    Kiyoshi Kurosawa                    78.0
# 5030             Color        Tadeo Garcia                     NaN
# 5031             Color  Thomas L. Phillips                    13.0
# 5032             Color     Ash Baron-Cohen                    10.0
# 5033             Color       Shane Carruth                   143.0
# 5034             Color    Neill Dela Llana                    35.0
# 5035             Color    Robert Rodriguez                    56.0
# 5036             Color     Anthony Vallone                     NaN
# 5037             Color        Edward Burns                    14.0
# 5038             Color         Scott Smith                     1.0
# 5039             Color                 NaN                    43.0
# 5040             Color    Benjamin Roberds                    13.0
# 5041             Color         Daniel Hsia                    14.0
# 5042             Color            Jon Gunn                    43.0

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4917 entries, 0 to 5042
# Data columns (total 24 columns):
# color                        4898 non-null object
# director_name                4815 non-null object
# num_critic_for_reviews       4868 non-null float64
# duration                     4902 non-null float64
# director_facebook_likes      4815 non-null float64
# actor_3_facebook_likes       4894 non-null float64
# actor_2_name                 4904 non-null object
# actor_1_facebook_likes       4910 non-null float64
# gross                        4054 non-null float64
# genres                       4917 non-null object
# actor_1_name                 4910 non-null object
# movie_title                  4917 non-null object
# num_voted_users              4917 non-null int64
# cast_total_facebook_likes    4917 non-null int64
# actor_3_name                 4894 non-null object
# plot_keywords                4765 non-null object
# num_user_for_reviews         4896 non-null float64
# language                     4905 non-null object
# country                      4912 non-null object
# content_rating               4617 non-null object
# budget                       4433 non-null float64
# actor_2_facebook_likes       4904 non-null float64
# imdb_score                   4917 non-null float64
# movie_facebook_likes         4917 non-null int64
# dtypes: float64(10), int64(3), object(11)
# memory usage: 960.4+ KB

# %%
df_copy=df_copy.reset_index(drop=True)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4917 entries, 0 to 4916
# Data columns (total 24 columns):
# color                        4898 non-null object
# director_name                4815 non-null object
# num_critic_for_reviews       4868 non-null float64
# duration                     4902 non-null float64
# director_facebook_likes      4815 non-null float64
# actor_3_facebook_likes       4894 non-null float64
# actor_2_name                 4904 non-null object
# actor_1_facebook_likes       4910 non-null float64
# gross                        4054 non-null float64
# genres                       4917 non-null object
# actor_1_name                 4910 non-null object
# movie_title                  4917 non-null object
# num_voted_users              4917 non-null int64
# cast_total_facebook_likes    4917 non-null int64
# actor_3_name                 4894 non-null object
# plot_keywords                4765 non-null object
# num_user_for_reviews         4896 non-null float64
# language                     4905 non-null object
# country                      4912 non-null object
# content_rating               4617 non-null object
# budget                       4433 non-null float64
# actor_2_facebook_likes       4904 non-null float64
# imdb_score                   4917 non-null float64
# movie_facebook_likes         4917 non-null int64
# dtypes: float64(10), int64(3), object(11)
# memory usage: 922.1+ KB

# %%
df_copy.groupby(['color']).count()
# Out:
#                   director_name  num_critic_for_reviews  duration  \
# color
#  Black and White            201                     204       204
# Color                      4597                    4648      4680
#
#                   director_facebook_likes  actor_3_facebook_likes  \
# color
#  Black and White                      201                     204
# Color                                4597                    4673
#
#                   actor_2_name  actor_1_facebook_likes  gross  genres  \
# color
#  Black and White           204                     204    136     204
# Color                     4682                    4687   3916    4694
#
#                   actor_1_name  ...  actor_3_name  plot_keywords  \
# color                           ...
#  Black and White           204  ...           204            201
# Color                     4687  ...          4673           4551
#
#                   num_user_for_reviews  language  country  content_rating  \
# color
#  Black and White                   204       201      204             189
# Color                             4675      4691     4691            4415
#
#                   budget  actor_2_facebook_likes  imdb_score  \
# color
#  Black and White     185                     204         204
# Color               4234                    4682        4694
#
#                   movie_facebook_likes
# color
#  Black and White                   204
# Color                             4694
#
# [2 rows x 23 columns]

# %%
df_copy['color']=df_copy['color'].map({"Color":1,"Black and  White":2,np.nan:3})

# %%
df_copy.iloc[4900:4905,0:3]
# Out:
#       color     director_name  num_critic_for_reviews
# 4900    1.0   Olivier Assayas                    81.0
# 4901    1.0      Jafar Panahi                    64.0
# 4902    NaN     Ivan Kavanagh                    12.0
# 4903    1.0  Kiyoshi Kurosawa                    78.0
# 4904    1.0      Tadeo Garcia                     NaN

# %%
df_copy['color'].fillna(3,inplace=True)

# %%
df_copy.iloc[4900:4905,0:3]
# Out:
#       color     director_name  num_critic_for_reviews
# 4900    1.0   Olivier Assayas                    81.0
# 4901    1.0      Jafar Panahi                    64.0
# 4902    3.0     Ivan Kavanagh                    12.0
# 4903    1.0  Kiyoshi Kurosawa                    78.0
# 4904    1.0      Tadeo Garcia                     NaN

# %%
df_copy.groupby(['color']).count()
# Out:
#        director_name  num_critic_for_reviews  duration  \
# color
# 1.0             4597                    4648      4680
# 3.0              218                     220       222
#
#        director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# color
# 1.0                       4597                    4673          4682
# 3.0                        218                     221           222
#
#        actor_1_facebook_likes  gross  genres  actor_1_name  ...  actor_3_name  \
# color                                                       ...
# 1.0                      4687   3916    4694          4687  ...          4673
# 3.0                       223    138     223           223  ...           221
#
#        plot_keywords  num_user_for_reviews  language  country  content_rating  \
# color
# 1.0             4551                  4675      4691     4691            4415
# 3.0              214                   221       214      221             202
#
#        budget  actor_2_facebook_likes  imdb_score  movie_facebook_likes
# color
# 1.0      4234                    4682        4694                  4694
# 3.0       199                     222         223                   223
#
# [2 rows x 23 columns]

# %%
df_copy['color']=df_copy['color'].astype(int)

# %%
df_copy.groupby(['color']).count()
# Out:
#        director_name  num_critic_for_reviews  duration  \
# color
# 1               4597                    4648      4680
# 3                218                     220       222
#
#        director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# color
# 1                         4597                    4673          4682
# 3                          218                     221           222
#
#        actor_1_facebook_likes  gross  genres  actor_1_name  ...  actor_3_name  \
# color                                                       ...
# 1                        4687   3916    4694          4687  ...          4673
# 3                         223    138     223           223  ...           221
#
#        plot_keywords  num_user_for_reviews  language  country  content_rating  \
# color
# 1               4551                  4675      4691     4691            4415
# 3                214                   221       214      221             202
#
#        budget  actor_2_facebook_likes  imdb_score  movie_facebook_likes
# color
# 1        4234                    4682        4694                  4694
# 3         199                     222         223                   223
#
# [2 rows x 23 columns]

# %%
df_copy.rename(columns={"director_facebook_likes":"director_fl","num_critic_for_reviews":"num_critics","actor_3_facebook_likes":"actor3_fl","actor_1_facebook_likes":"actor1_fl","actor_2_facebook_likes":"actor2_fl","movie_facebook_likes":"movie_fl","num_user_for_reviews":"num_users"},inplace=True)

# %%
df_copy.head()
# Out:
#    color      director_name  num_critics  duration  director_fl  actor3_fl  \
# 0      1      James Cameron        723.0     178.0          0.0      855.0
# 1      1     Gore Verbinski        302.0     169.0        563.0     1000.0
# 2      1         Sam Mendes        602.0     148.0          0.0      161.0
# 3      1  Christopher Nolan        813.0     164.0      22000.0    23000.0
# 4      3        Doug Walker          NaN       NaN        131.0        NaN
#
#        actor_2_name  actor1_fl        gross                           genres  \
# 0  Joel David Moore     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1     Orlando Bloom    40000.0  309404152.0         Action|Adventure|Fantasy
# 2      Rory Kinnear    11000.0  200074175.0        Action|Adventure|Thriller
# 3    Christian Bale    27000.0  448130642.0                  Action|Thriller
# 4        Rob Walker      131.0          NaN                      Documentary
#
#    ...          actor_3_name  \
# 0  ...             Wes Studi
# 1  ...        Jack Davenport
# 2  ...      Stephanie Sigman
# 3  ...  Joseph Gordon-Levitt
# 4  ...                   NaN
#
#                                        plot_keywords  num_users  language  \
# 0             avatar|future|marine|native|paraplegic     3054.0   English
# 1  goddess|marriage ceremony|marriage proposal|pi...     1238.0   English
# 2                bomb|espionage|sequel|spy|terrorist      994.0   English
# 3  deception|imprisonment|lawlessness|police offi...     2701.0   English
# 4                                                NaN        NaN       NaN
#
#   country content_rating       budget actor2_fl imdb_score movie_fl
# 0     USA          PG-13  237000000.0     936.0        7.9    33000
# 1     USA          PG-13  300000000.0    5000.0        7.1        0
# 2      UK          PG-13  245000000.0     393.0        6.8    85000
# 3     USA          PG-13  250000000.0   23000.0        8.5   164000
# 4     NaN            NaN          NaN      12.0        7.1        0
#
# [5 rows x 24 columns]

# %%
df_copy['num_critics'].plot()

# %%
df_copy['num_critics'].hist(bins=50,color='k')

# %%
df_copy['gross'].hist(bins=100,color='k')

# %%
x=df_copy['budget']/10000000
x.hist(bins=95,color='k')

# %%
fig,ax=plt.subplots(figsize=(20,20))
df_copy['genres'].value_counts().plot(ax=ax)

# %%
len(df_copy)
# Out:
# 4917

# %%
df_copy.shape
# Out:
# (4917, 24)

# %%
df_copy.iloc[2,3]
# Out:
# 148.0

# %%
x=df_copy.isnull().sum(axis=1).tolist()
for index,i in enumerate(x):
    if i>=8:
        print((index,i))
        df_copy=df_copy.drop(index).reset_index(drop=True)
# Out:
# (4, 11)
# (276, 12)
# (2119, 8)
# (2214, 9)
# (2313, 8)
# (4419, 8)
# (4823, 10)
# (4824, 8)
# (4865, 8)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4908 entries, 0 to 4907
# Data columns (total 24 columns):
# color                        4908 non-null int32
# director_name                4806 non-null object
# num_critics                  4860 non-null float64
# duration                     4894 non-null float64
# director_fl                  4806 non-null float64
# actor3_fl                    4886 non-null float64
# actor_2_name                 4895 non-null object
# actor1_fl                    4901 non-null float64
# gross                        4049 non-null float64
# genres                       4908 non-null object
# actor_1_name                 4901 non-null object
# movie_title                  4908 non-null object
# num_voted_users              4908 non-null int64
# cast_total_facebook_likes    4908 non-null int64
# actor_3_name                 4886 non-null object
# plot_keywords                4758 non-null object
# num_users                    4888 non-null float64
# language                     4897 non-null object
# country                      4904 non-null object
# content_rating               4609 non-null object
# budget                       4425 non-null float64
# actor2_fl                    4895 non-null float64
# imdb_score                   4908 non-null float64
# movie_fl                     4908 non-null int64
# dtypes: float64(10), int32(1), int64(3), object(10)
# memory usage: 901.2+ KB

# %%
df_copy['content_rating'].value_counts().plot(kind='bar')

# %%
df_copy['content_rating'].fillna(0,inplace=True)
content_mapping={"R":1,"PG-13":2,"PG":3,"Not Rated":4,"G":5,"Unrated":6,"Approved":7,"TV-14":8,"TV-MA":9,"TV-PG":10,"X":11,"TV-G":12,"Passed":13,"NC-17":14,"GP":15,"M":16,"TV-Y7":17,"TV-Y":18}
df_copy['content_rating']=df_copy['content_rating'].map(content_mapping)

# %%
df_copy.groupby(['content_rating']).count()
# Out:
#                 color  director_name  num_critics  duration  director_fl  \
# content_rating
# 1.0              2064           2064         2061      2063         2064
# 2.0              1408           1408         1399      1407         1408
# 3.0               685            685          685       685          685
# 4.0               115            114          113       115          114
# 5.0               112            112          111       112          112
# 6.0                59             59           57        59           59
# 7.0                54             54           54        54           54
# 8.0                30              3           29        29            3
# 9.0                18              0           18        18            0
# 10.0               13              3           11        13            3
# 11.0               12             12           12        12           12
# 12.0               10              4           10        10            4
# 13.0                9              9            9         9            9
# 14.0                7              7            7         7            7
# 15.0                6              6            6         6            6
# 16.0                5              5            5         5            5
# 17.0                1              0            1         1            0
# 18.0                1              0            1         1            0
#
#                 actor3_fl  actor_2_name  actor1_fl  gross  genres  ...  \
# content_rating                                                     ...
# 1.0                  2063          2064       2064   1816    2064  ...
# 2.0                  1406          1407       1408   1349    1408  ...
# 3.0                   684           685        685    595     685  ...
# 4.0                   112           114        114     57     115  ...
# 5.0                   110           112        112     95     112  ...
# 6.0                    59            59         59     34      59  ...
# 7.0                    54            54         54     18      54  ...
# 8.0                    30            30         30      0      30  ...
# 9.0                    18            18         18      1      18  ...
# 10.0                   13            13         13      0      13  ...
# 11.0                   12            12         12      9      12  ...
# 12.0                   10            10         10      0      10  ...
# 13.0                    9             9          9      3       9  ...
# 14.0                    7             7          7      6       7  ...
# 15.0                    6             6          6      1       6  ...
# 16.0                    5             5          5      2       5  ...
# 17.0                    1             1          1      0       1  ...
# 18.0                    1             1          1      0       1  ...
#
#                 cast_total_facebook_likes  actor_3_name  plot_keywords  \
# content_rating
# 1.0                                  2064          2063           2036
# 2.0                                  1408          1406           1393
# 3.0                                   685           684            671
# 4.0                                   115           112            105
# 5.0                                   112           110            112
# 6.0                                    59            59             58
# 7.0                                    54            54             54
# 8.0                                    30            30             28
# 9.0                                    18            18             17
# 10.0                                   13            13             12
# 11.0                                   12            12             12
# 12.0                                   10            10              9
# 13.0                                    9             9              9
# 14.0                                    7             7              7
# 15.0                                    6             6              6
# 16.0                                    5             5              5
# 17.0                                    1             1              1
# 18.0                                    1             1              1
#
#                 num_users  language  country  budget  actor2_fl  imdb_score  \
# content_rating
# 1.0                  2062      2063     2064    1908       2064        2064
# 2.0                  1407      1408     1408    1329       1407        1408
# 3.0                   685       682      685     642        685         685
# 4.0                   114       113      115      88        114         115
# 5.0                   112       112      112     107        112         112
# 6.0                    59        59       59      47         59          59
# 7.0                    54        54       54      49         54          54
# 8.0                    29        30       29       5         30          30
# 9.0                    18        18       17       1         18          18
# 10.0                   13        13       13       3         13          13
# 11.0                   12        12       12      12         12          12
# 12.0                   10        10       10       5         10          10
# 13.0                    9         9        9       9          9           9
# 14.0                    7         7        7       7          7           7
# 15.0                    6         6        6       4          6           6
# 16.0                    5         5        5       4          5           5
# 17.0                    1         1        1       0          1           1
# 18.0                    1         1        1       0          1           1
#
#                 movie_fl
# content_rating
# 1.0                 2064
# 2.0                 1408
# 3.0                  685
# 4.0                  115
# 5.0                  112
# 6.0                   59
# 7.0                   54
# 8.0                   30
# 9.0                   18
# 10.0                  13
# 11.0                  12
# 12.0                  10
# 13.0                   9
# 14.0                   7
# 15.0                   6
# 16.0                   5
# 17.0                   1
# 18.0                   1
#
# [18 rows x 23 columns]

# %%
df_copy['content_rating'].fillna(0,inplace=True)

# %%
df_copy.groupby(['content_rating']).count()
# Out:
#                 color  director_name  num_critics  duration  director_fl  \
# content_rating
# 0.0               299            261          271       288          261
# 1.0              2064           2064         2061      2063         2064
# 2.0              1408           1408         1399      1407         1408
# 3.0               685            685          685       685          685
# 4.0               115            114          113       115          114
# 5.0               112            112          111       112          112
# 6.0                59             59           57        59           59
# 7.0                54             54           54        54           54
# 8.0                30              3           29        29            3
# 9.0                18              0           18        18            0
# 10.0               13              3           11        13            3
# 11.0               12             12           12        12           12
# 12.0               10              4           10        10            4
# 13.0                9              9            9         9            9
# 14.0                7              7            7         7            7
# 15.0                6              6            6         6            6
# 16.0                5              5            5         5            5
# 17.0                1              0            1         1            0
# 18.0                1              0            1         1            0
#
#                 actor3_fl  actor_2_name  actor1_fl  gross  genres  ...  \
# content_rating                                                     ...
# 0.0                   286           288        293     63     299  ...
# 1.0                  2063          2064       2064   1816    2064  ...
# 2.0                  1406          1407       1408   1349    1408  ...
# 3.0                   684           685        685    595     685  ...
# 4.0                   112           114        114     57     115  ...
# 5.0                   110           112        112     95     112  ...
# 6.0                    59            59         59     34      59  ...
# 7.0                    54            54         54     18      54  ...
# 8.0                    30            30         30      0      30  ...
# 9.0                    18            18         18      1      18  ...
# 10.0                   13            13         13      0      13  ...
# 11.0                   12            12         12      9      12  ...
# 12.0                   10            10         10      0      10  ...
# 13.0                    9             9          9      3       9  ...
# 14.0                    7             7          7      6       7  ...
# 15.0                    6             6          6      1       6  ...
# 16.0                    5             5          5      2       5  ...
# 17.0                    1             1          1      0       1  ...
# 18.0                    1             1          1      0       1  ...
#
#                 cast_total_facebook_likes  actor_3_name  plot_keywords  \
# content_rating
# 0.0                                   299           286            222
# 1.0                                  2064          2063           2036
# 2.0                                  1408          1406           1393
# 3.0                                   685           684            671
# 4.0                                   115           112            105
# 5.0                                   112           110            112
# 6.0                                    59            59             58
# 7.0                                    54            54             54
# 8.0                                    30            30             28
# 9.0                                    18            18             17
# 10.0                                   13            13             12
# 11.0                                   12            12             12
# 12.0                                   10            10              9
# 13.0                                    9             9              9
# 14.0                                    7             7              7
# 15.0                                    6             6              6
# 16.0                                    5             5              5
# 17.0                                    1             1              1
# 18.0                                    1             1              1
#
#                 num_users  language  country  budget  actor2_fl  imdb_score  \
# content_rating
# 0.0                   284       294      297     205        288         299
# 1.0                  2062      2063     2064    1908       2064        2064
# 2.0                  1407      1408     1408    1329       1407        1408
# 3.0                   685       682      685     642        685         685
# 4.0                   114       113      115      88        114         115
# 5.0                   112       112      112     107        112         112
# 6.0                    59        59       59      47         59          59
# 7.0                    54        54       54      49         54          54
# 8.0                    29        30       29       5         30          30
# 9.0                    18        18       17       1         18          18
# 10.0                   13        13       13       3         13          13
# 11.0                   12        12       12      12         12          12
# 12.0                   10        10       10       5         10          10
# 13.0                    9         9        9       9          9           9
# 14.0                    7         7        7       7          7           7
# 15.0                    6         6        6       4          6           6
# 16.0                    5         5        5       4          5           5
# 17.0                    1         1        1       0          1           1
# 18.0                    1         1        1       0          1           1
#
#                 movie_fl
# content_rating
# 0.0                  299
# 1.0                 2064
# 2.0                 1408
# 3.0                  685
# 4.0                  115
# 5.0                  112
# 6.0                   59
# 7.0                   54
# 8.0                   30
# 9.0                   18
# 10.0                  13
# 11.0                  12
# 12.0                  10
# 13.0                   9
# 14.0                   7
# 15.0                   6
# 16.0                   5
# 17.0                   1
# 18.0                   1
#
# [19 rows x 23 columns]

# %%
df_copy['content_rating'].astype(int)
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 4903    0
# 4904    8
# 4905    0
# 4906    2
# 4907    3
# Name: content_rating, Length: 4908, dtype: int32

# %%
ax=plt.subplots(figsize=(10,10))
plt.scatter(x=df_copy['content_rating'],y=df_copy['imdb_score'])

# %%
df_copy[['imdb_score','content_rating']].groupby(['content_rating']).mean().sort_values('imdb_score',ascending=False)
# Out:
#                 imdb_score
# content_rating
# 9.0               8.244444
# 18.0              7.400000
# 10.0              7.353846
# 7.0               7.327778
# 8.0               7.250000
# 17.0              7.200000
# 13.0              7.166667
# 12.0              6.920000
# 15.0              6.916667
# 6.0               6.889831
# 16.0              6.840000
# 4.0               6.621739
# 14.0              6.542857
# 5.0               6.529464
# 1.0               6.524467
# 11.0              6.416667
# 0.0               6.402007
# 3.0               6.288321
# 2.0               6.254830

# %%
df_copy.hist(bins=30,figsize=(15,15),color='g')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002497E0D0408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002497E23C488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002497DBD7E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002497DBEF7C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002497DC0C1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002497DC41B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002497DC7A548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002497DCB9F88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002497DCC2088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002497DCFA248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002497DD5D808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002497DD95888>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002497DDCD988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002497DE06AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002497DE3EBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002497DE78CC8>]],
#       dtype=object)

# %%
df_copy.columns
# Out:
# Index(['color', 'director_name', 'num_critics', 'duration', 'director_fl',
#        'actor3_fl', 'actor_2_name', 'actor1_fl', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'cast_total_facebook_likes', 'actor_3_name', 'plot_keywords',
#        'num_users', 'language', 'country', 'content_rating', 'budget',
#        'actor2_fl', 'imdb_score', 'movie_fl'],
#       dtype='object')

# %%
#creating a different dataframe to analyse the most affecting features
df_a=df_copy[['num_critics','duration','num_voted_users','num_users','director_fl']]

# %%
df_a.head(2)
# Out:
#    num_critics  duration  num_voted_users  num_users  director_fl
# 0        723.0     178.0           886204     3054.0          0.0
# 1        302.0     169.0           471220     1238.0        563.0

# %%
df_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4908 entries, 0 to 4907
# Data columns (total 5 columns):
# num_critics        4860 non-null float64
# duration           4894 non-null float64
# num_voted_users    4908 non-null int64
# num_users          4888 non-null float64
# director_fl        4806 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 191.8 KB

# %%
#filling na values
df_a["num_critics"].fillna(df_copy["num_critics"].mean(),inplace=True)
df_a["duration"].fillna(df_copy["duration"].mean(),inplace=True)
df_a["director_fl"].fillna(df_copy["director_fl"].mean(),inplace=True)
df_a["num_users"].fillna(df_copy["num_users"].mean(),inplace=True)
df_a["num_voted_users"].fillna(df_copy["num_voted_users"].mean(),inplace=True)

# %%
df_a.columns
# Out:
# Index(['num_critics', 'duration', 'num_voted_users', 'num_users',
#        'director_fl', 'director_facebook_likes'],
#       dtype='object')

# %%
df_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4908 entries, 0 to 4907
# Data columns (total 5 columns):
# num_critics        4908 non-null float64
# duration           4908 non-null float64
# num_voted_users    4908 non-null int64
# num_users          4908 non-null float64
# director_fl        4908 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 191.8 KB

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df_a,df_copy['imdb_score'])

# %%
x_train.head(2)
# Out:
#       num_critics  duration  num_voted_users  num_users  director_fl
# 623         141.0     124.0           101899      445.0          0.0
# 2823        111.0      93.0            21530      159.0         16.0

# %%
y_train.head(2)
# Out:
# 623     6.8
# 2823    6.1
# Name: imdb_score, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
reg=LinearRegression().fit(x_train,y_train)

# %%
prec_lrm=reg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
print('The mean squared error using Linear regression is: ',mean_squared_error(y_test,prec_lrm))
print('The mean absolute error using Linear regression is: ',mean_absolute_error(y_test,prec_lrm))
# Out:
# The mean squared error using Linear regression is:  0.988691756460864
# The mean absolute error using Linear regression is:  0.7597569841816281

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# C:\Users\HP Pavilion\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
prec_rf=rf.predict(x_test)

# %%
print('The mean squared error using Random Forest model is: ',mean_squared_error(y_test,prec_rf))
print('The mean absolute error using Random Forest model is: ',mean_absolute_error(y_test,prec_rf))
# Out:
# The mean squared error using Random Forest model is:  0.9590774246128769
# The mean absolute error using Random Forest model is:  0.7477098614506927
